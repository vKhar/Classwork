# %% [markdown]
# Task 3.3
# when performing white box testing, the tester knows the content of the code and how the program is coded,
# whereas in black box testing, the tester does not know how the content is coded but knows what the code
# is supposed to do and not do.

# %% [markdown]
# 2/2

# %%
#task 3.1

f = open('BianLingzhu/NAMES.TXT') 
lines = f.readlines()
players =[]
for line in lines:
    line = line.strip()
    players.append(line)

# %% [markdown]
# 2/2

# %%
def whoWins(players,m): 
    m=0
    if len(players) < 1:
        print('Please input a list of players that has more than 1 player')
    while True:
        m += m
        if m > len(players):
            m - len(players)
        players.pop(m)
        if len(players) == 1:
            print(f'the winner is {players[0]}!')
            break
whoWins(players,1)

# %% [markdown]
# - line 8, you mean m = m - len(players) ?!!!
# - did not re-start with the next player, always start at the beginning
# - 3/6

# %%
#Task 3.4
Valid test cases
whoWins(players,1)
Wakefield


invalid test cases
whoWins('hello')
runtime error

whoWins(3)
runtime error


boundary
whoWins([],1)
Please input a list of players that has more than 1 player

# %% [markdown]
# - for test cases you need to show the valid, invalid or boundary input data NOt how the call is invoke with wrong arguments
# - no code to show execution of test cases
# - 2/5

# %% [markdown]
# ### Total
# 9/15
