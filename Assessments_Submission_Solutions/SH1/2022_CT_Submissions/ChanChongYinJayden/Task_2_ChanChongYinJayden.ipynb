# %%
# Task 2.1
def re_sum(a,r,m):
    # def recur():
    if m-1 == 0:
        return a
    else:
        return a*(r**(m-1)) + re_sum(a,r,m-1),

# %% [markdown]
# - terms not returned
# 3/6

# %% [markdown]
# # Task 2.2

# %% [markdown]
# 0/4

# %% [markdown]
# # Task 2.3
# An iterative approach would consume less memory as it does not store all the calls of the function in a call stack like a recursive approach wounld. However, it could be less intuitive so such a problem would be easier to solve recursively.

# %% [markdown]
# 2/2
#
# ### Total
# 5/12
