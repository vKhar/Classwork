# %%
#Task 4.1:
class Staff:
    def __init__(self,name,appt,base_salary):
        self.__name = str(name)
        self.__appt = str(appt)
        self.__base_salary = int(base_salary)
    def calc_annual_salary(self):
        return self.__base_salary * 12
    def __repr__(self):
        return f"<{self.__name}:{self.__appt}:{self.__base_salary* 12}>"
    def get_name(self):
        return self.__name
    def get_appt(self):
        return self.__appt
    def get_base_salary(self):
        return self.__base_salary
    def set_name(self,name):
        
        self.__name = str(name)
    def set_appt(self,appt):
        self.__appt = appt
    def set_base_salary(self,base_salary):
        self.__base_salary = base_salary

# %% [markdown]
# - base_salary is a float not int
# - 3/4

# %%
#Task 4.2
class PermStaff(Staff):
    def __init__(self, name, appt, base_salary, bonus_rating):
        super().__init__(name, appt, base_salary)
        self.__bonus_rating = bonus_rating
    def get_bonus_rating(self):
        return self.__bonus_rating
    def calc_annual_salary(self):
        
        return f"{self.get_base_salary * 12} + {self.get_base_salary * 12 * self.__bonus_rating}"
    
#john = PermStaff("JOJO","10",1000,0.8)
#print(john.calc_annual_salary())
# Out:
# 12000 + 9600.0

# %%
#Task 4.2
class CommisionStaff(Staff):
    def __init__(self,name,appt,base_salary,commision_rate,revenue_generated):
        super().__init__(name,appt,base_salary)
        self.__commision_rate = commision_rate
        self.__revenue_generated = revenue_generated
    def calc_annual_salary(self):
        return f"{self.get_base_salary() * 12} + {self.__revenue_generated * self.__commision_rate}"

# %% [markdown]
# - getters/setters for CommisionStaff ?
# - all the getters are  methods calls
# - 2/4

# %%
#Task 4.3
with open("LeeZiZhuo/STAFF.CSV","r") as f:
    my_list = list()
    staff_list = list()
    words = f.readlines()
    for word in words:
        word = word.strip()
        my_list.append(word)
    
    my_list.remove(my_list[0])
    
    for item in my_list:
        item = item.strip(",").split(",")
        item = ",".join(item)
        print(item)
        staff_list.append(Staff(str(item)))
        
    print(staff_list)

# %% [markdown]
# - line 16 Staff constructor requires name,appt base_salary
# - appropitae classes should be use, Staff, PermStaff, CommisionStaff depending on the data in the file
# - 2/4

# %% [markdown]
# 4.5
# - 0/4
#
# 4.6
# - 0/6
#
# ### Total
# 7/22
