# %%
def calc_score(throws):
    lst=[]
    frame_score=0
    count=0
    a=1
    for i in throws:
        if i == 'X':
            lst.append(10)
        else:
            lst.append(int(i))

    for i in lst:
        if i<10:
            count+=1
    if lst[-3]==10:
        a=1
        while len(lst)>3:
            if lst[0]==10:
                frame_score=frame_score+10+lst[1]+lst[2]
                lst.pop(0)
                print (frame_score)
            elif lst[0]+lst[1]==10:
                frame_score=frame_score+10+lst[2]
                lst.pop(0)
                lst.pop(0)
                print (frame_score)
            else:
                frame_score=frame_score+lst[0]+lst[1]
                lst.pop(0)
                lst.pop(0)
                print (frame_score)
            print(lst)
        print (frame_score+lst[0]+lst[1]+lst[2])
    elif count%2==0:
        a=2
        while len(lst)>2:
            if lst[0]==10:
                frame_score=frame_score+10+lst[1]+lst[2]
                lst.pop(0)
                print (frame_score)
            elif lst[0]+lst[1]==10:
                frame_score=frame_score+10+lst[2]
                lst.pop(0)
                lst.pop(0)
                print (frame_score)
            else:
                frame_score=frame_score+lst[0]+lst[1]
                lst.pop(0)
                lst.pop(0)
                print (frame_score)
            print(lst)
        print (frame_score+lst[0]+lst[1])
    else:
        a=3
        while len(lst)>3:
            if lst[0]==10:
                frame_score=frame_score+10+lst[1]+lst[2]
                lst.pop(0)
                print (frame_score)
            elif lst[0]+lst[1]==10:
                frame_score=frame_score+10+lst[2]
                lst.pop(0)
                lst.pop(0)
                print (frame_score)
            else:
                frame_score=frame_score+lst[0]+lst[1]
                lst.pop(0)
                lst.pop(0)
                print (frame_score)
            print(lst)
        print (frame_score+lst[0]+lst[1]+lst[2])
