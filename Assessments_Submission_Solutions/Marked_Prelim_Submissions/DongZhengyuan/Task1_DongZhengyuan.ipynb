# %%
#Task 1.1
class Node:
    def __init__(self, data): #attributes are public as they will be referrenced by other classes
        self.data = data
        self.next = None
        
class LL:
    def __init__(self):
        self.start = None #when empty
    def is_empty(self):
        if not self.start:
            return True
        return False
    def insert_front(self, data):
        new_node = Node(data)
        if self.is_empty():
            self.start = new_node
            return
        new_node.next = self.start
        self.start = new_node
        return
    def remove_front(self): #removes and returns item
        if not self.is_empty():
            ret = self.start.data
            #print(self.start.next.data)
            if self.start.next:
                self.start = self.start.next
            else:
                self.start = None
            return ret
        return None
    def __repr__(self):
        ret = []
        if self.is_empty():
            return ret
        cur = self.start
        while cur:
            ret.append(cur.data)
            cur = cur.next
        return ','.join(ret)

# %% [markdown]
# - line 26-29:  redundent code it doesn't matter what self.start.next is!!
# - line 35 , [] is not a str, __repr__ must return a str
# - 7m

# %%
#Task 1.2
class Node:
    def __init__(self, data): #attributes are public as they will be referrenced by other classes
        self.data = data
        self.next = None
        
class LL:
    def __init__(self):
        self.start = None #when empty
    def is_empty(self):
        if not self.start:
            return True
        return False
    def insert_front(self, data):
        new_node = Node(data)
        if self.is_empty():
            self.start = new_node
            return
        new_node.next = self.start
        self.start = new_node
        return
    def remove_front(self): #removes and returns item
        if not self.is_empty():
            ret = self.start.data
            #print(self.start.next.data)
            if self.start.next:
                self.start = self.start.next
            else:
                self.start = None
            return ret
        return None
    def __repr__(self):
        ret = []
        if self.is_empty():
            return ret
        cur = self.start
        while cur:
            ret.append(cur.data)
            cur = cur.next
        return ','.join(ret)

# %% [markdown]
# 4m

# %%
#Task 1.3
class Node:
    def __init__(self, data): #attributes are public as they will be referrenced by other classes
        self.data = data
        self.next = None
        
class LL:
    def __init__(self):
        self.start = None #when empty
    def is_empty(self):
        if not self.start:
            return True
        return False
    def insert_front(self, data):
        new_node = Node(data)
        if self.is_empty():
            self.start = new_node
            return
        new_node.next = self.start
        self.start = new_node
        return
    def remove_front(self): #removes and returns item
        if not self.is_empty():
            ret = self.start.data
            #print(self.start.next.data)
            if self.start.next:
                self.start = self.start.next
            else:
                self.start = None
            return ret
        return None
    def __repr__(self):
        ret = []
        if self.is_empty():
            return ret
        cur = self.start
        while cur:
            ret.append(cur.data)
            cur = cur.next
        return ','.join(ret)

class Stack:
    def __init__(self):
        self.top = LL()
    def push(self, item): #item is an object
        self.top.insert_front(item)
        return
    def pop(self): #returns object
        return self.top.remove_front()
    def peek(self):
        return self.top.start.data
    def is_empty(self):
        return self.top.is_empty()

#Test cases
s = Stack() #assume objects are integers
s.push(5)
s.push(2)
s.push(3)
print(s.peek())
print(s.is_empty())
print(s.pop())
print(s.pop())
print(s.pop())
print(s.pop())
print(s.is_empty())

# %% [markdown]
# 1

# %%
#Task 1.5
class Node:
    def __init__(self, data): #attributes are public as they will be referrenced by other classes
        self.data = data
        self.next = None
        
class LL:
    def __init__(self):
        self.start = None #when empty
    def is_empty(self):
        if not self.start:
            return True
        return False
    def insert_front(self, data):
        new_node = Node(data)
        if self.is_empty():
            self.start = new_node
            return
        new_node.next = self.start
        self.start = new_node
        return
    def remove_front(self): #removes and returns item
        if not self.is_empty():
            ret = self.start.data
            #print(self.start.next.data)
            if self.start.next:
                self.start = self.start.next
            else:
                self.start = None
            return ret
        return None
    def __repr__(self):
        ret = []
        if self.is_empty():
            return ret
        cur = self.start
        while cur:
            ret.append(cur.data)
            cur = cur.next
        return ','.join(ret)

class Stack:
    def __init__(self):
        self.top = LL()
    def push(self, item): #item is an object
        self.top.insert_front(item)
        return
    def pop(self): #returns object
        return self.top.remove_front()
    def peek(self):
        return self.top.start.data
    def is_empty(self):
        return self.top.is_empty()
    
class Queue(Stack):
    def __init__(self):
        super().__init__()
    def enqueue(self, item):
        if self.top.is_empty():
            self.push(item)
            return
        new_node = Node(item)
        cur = self.top.start
        while True:
            if not cur: #if end of LL is reached
                prev.next = new_node
                #print(self.top)
                return
            prev = cur
            cur = cur.next
    def dequeue(self):
        return self.pop()

#Test cases
q = Queue() #assume objects are integers
q.enqueue(5)
q.enqueue(2)
q.enqueue(3)
print(q.dequeue())
print(q.dequeue())
#print(q.top.start.data)
print(q.dequeue())
print(q.dequeue())

# %% [markdown]
# - A Queue is NOT a Stack, there is no inheritance (is-a) relationship, when you use a Stack , you have to create a stack in your Queue code. This is a has-a relationship.
# You cannot traverse the linked list to perfrom enqueue, you are breaking the Stack abstraction which the question required you to use!
# - 1m

# %%
#Task 1.6
class Node:
    def __init__(self, data): #attributes are public as they will be referrenced by other classes
        self.data = data
        self.next = None
        
class LL:
    def __init__(self):
        self.start = None #when empty
    def is_empty(self):
        if not self.start:
            return True
        return False
    def insert_front(self, data):
        new_node = Node(data)
        if self.is_empty():
            self.start = new_node
            return
        new_node.next = self.start
        self.start = new_node
        return
    def remove_front(self): #removes and returns item
        if not self.is_empty():
            ret = self.start.data
            #print(self.start.next.data)
            if self.start.next:
                self.start = self.start.next
            else:
                self.start = None
            return ret
        return None
    def __repr__(self):
        ret = []
        if self.is_empty():
            return ret
        cur = self.start
        while cur:
            ret.append(cur.data)
            cur = cur.next
        return ','.join(ret)

class Stack:
    def __init__(self):
        self.top = LL()
    def push(self, item): #item is an object
        self.top.insert_front(item)
        return
    def pop(self): #returns object
        return self.top.remove_front()
    def peek(self):
        return self.top.start.data
    def is_empty(self):
        return self.top.is_empty()
    
class Queue(Stack):
    def __init__(self):
        super().__init__()
    def enqueue(self, item):
        if self.top.is_empty():
            self.push(item)
            return
        new_node = Node(item)
        cur = self.top.start
        while True:
            if not cur: #if end of LL is reached
                prev.next = new_node
                #print(self.top)
                return
            prev = cur
            cur = cur.next
    def dequeue(self):
        return self.pop()

class MaxQueue(Queue):
    def __init__(self):
        super().__init__()
    def peek_max(self): #returns item with the highest value.
        if self.is_empty():
            return None
        cur = self.top.start
        maximum = cur.data
        while cur:
            if cur.data > maximum:
                maximum = cur.data
            cur = cur.next
        return maximum

M = MaxQueue()
print(M.peek_max())
M.enqueue(5)
M.enqueue(2)
M.enqueue(3)
print(M.peek_max())

# %% [markdown]
# - break abstraction to find max value
# - 2m
