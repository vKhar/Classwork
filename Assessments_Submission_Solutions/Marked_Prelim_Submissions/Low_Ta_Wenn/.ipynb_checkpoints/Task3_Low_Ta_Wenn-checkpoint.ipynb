# %%
# task 3.1

def qsort(words):
    if len(words) < 2:
        return words
    else:
        pivot = words[0]
        left = []
        right = []
        for i in range(1, len(words)):
            if pivot[0] > words[i][0]: # comparing the first element of tuples
                left.append(words[i])
            else:
                right.append(words[i])
        return qsort(left) + [pivot] + qsort(right)

# %%
# task 3.2

#valid case
newlist = [("Orange", 23), ("Apple", 121), ("Mango", 2), ("Durian", 4)]
print(qsort(newlist))

#boundary case
newlist = []
print(qsort(newlist))

#invalid case due to max call stack exceeded
newlist = [(3, 1) for i in range(3001)]
print(qsort(newlist))
# Out:
# [('Apple', 121), ('Durian', 4), ('Mango', 2), ('Orange', 23)]
# []
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-9-569850cc6a20> in <module>()
#      11 #invalid case due to max call stack exceeded
#      12 newlist = [(3, 1) for i in range(3001)]
# ---> 13 print(qsort(newlist))
#
# <ipython-input-2-25ba0a695768> in qsort(words)
#      13             else:
#      14                 right.append(words[i])
# ---> 15         return qsort(left) + [pivot] + qsort(right)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-2-25ba0a695768> in qsort(words)
#      13             else:
#      14                 right.append(words[i])
# ---> 15         return qsort(left) + [pivot] + qsort(right)
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
# task 3.3

temp_storage = []
line_count = 1 # first line is 1
sorted_partial = []


temp_pointer = 0 #points to the index of the list in sorted_partial that is not yet 3000 in length
with open("WORDS.TXT") as f:
    for line in f:
        temp_storage.append((line.strip(), line_count))
        if len(temp_storage) == 2999:
            sorted_temp = qsort(temp_storage) # sorts the list with 2999 items inside
            sorted_partial.append(sorted_temp)
            temp_storage = [] # reset temp
        line_count += 1
print(sorted_partial)

def merge(a, b): # a and b are sorted lists
    ret = []
    while len(a) and len(b):
        if a[0] > b[0]: # compares each item in a and b and appends smaller item to ret, making ret sorted
            ret.append(b.pop(0))
        else:
            ret.append(a.pop(0))
    return ret + a + b

def m_sort(arr):
    if len(arr) < 2:
        return arr
    else:
        mid = len(arr)//2
        return merge(m_sort(arr[mid]), m_sort(arr[mid+1]))

sorted_all = m_sort(sorted_partial)
# Out:
# [[('abbreviates', 1331), ('abe', 2006), ('abnormality', 2565), ('abolition', 2145), ('aboriginal', 2882), ('abortively', 1549), ('abrasives', 1434), ('abrogators', 682), ('abscising', 1790), ('absorbedly', 2319), ('absorbers', 474), ('abstain', 2496), ('abstracted', 2721), ('abstracting', 2337), ('acanthuses', 156), ('accedes', 2007), ('acceleration', 2868), ('accouterments', 993), ('achiever', 1339), ('acknowledging', 243), ('acquitted', 2131), ('acridly', 969), ('actives', 1712), ('actually', 1130), ('addict', 2574), ('adductor', 932), ('adenines', 1568), ('adhesives', 1178), ('adiabatic', 2348), ('adjacent', 867), ('adjourns', 2288), ('adjurations', 2606), ('admirers', 512), ('admixtures', 1990), ('ado', 412), ('adroitness', 2773), ('adulates', 1030), ('adulterous', 616), ('advancements', 1309), ('advent', 1057), ('adventurously', 2697), ('aerobe', 657), ('aerodynamic', 530), ('aeronautic', 1641), ('aeroplane', 2732), ('aerosol', 1031), ('affidavits', 1965), ('affiliations', 222), ('affirmants', 238), ('aforesaid', 1065), ('africa', 774), ('afterdecks', 2767), ('afterimages', 987), ('agencies', 290), ('aggrandize', 2488), ('aggrandizement', 1258), ('aggravate', 1810), ('aggression', 1230), ('aggrieves', 1961), ('aghast', 2712), ('agister', 2861), ('agistment', 2546), ('agoraphobia', 2409), ('aiders', 1951), ('ailment', 1041), ('aimless', 2080), ('airdrome', 1647), ('akimbo', 2652), ('alarm', 1670), ('alcove', 2128), ('aleck', 1697), ('aliens', 1718), ('alkalinising', 2284), ('alkalosis', 2956), ('allays', 8), ('allegorizes', 1927), ('alleviated', 1830), ('alliterates', 1334), ('allocatur', 2059), ('allomorphs', 121), ('allotropes', 2332), ('allotropic', 2915), ('alpenhorns', 686), ('alphabet', 1328), ('alternators', 485), ('althea', 873), ('although', 1378), ('altocumulus', 1291), ('amalgamate', 605), ('amarillo', 2548), ('amazonian', 543), ('ambits', 1192), ('ambling', 702), ('ambulate', 386), ('ambushed', 284), ('amendments', 2221), ('amerce', 1058), ('amex', 2566), ('amid', 1744), ('amis', 2374), ('ammunition', 1267), ('amoebae', 2042), ('amore', 1427), ('amorphous', 2543), ('ampleness', 1395), ('anabolism', 792), ('anachronistic', 883), ('anaesthetics', 2242), ('anatomically', 2459), ('anatomize', 1576), ('ancestral', 606), ('anchorage', 751), ('anchormen', 31), ('anesthesia', 2298), ('anesthetist', 1102), ('angels', 2318), ('angrier', 817), ('angrily', 1849), ('angst', 1878), ('anguishing', 435), ('anklebones', 1290), ('annette', 1002), ('anoint', 527), ('anointed', 57), ('antagonising', 691), ('antagonistic', 2885), ('antediluvians', 200), ('antepenult', 505), ('anterior', 823), ('anticyclones', 1981), ('antihero', 1121), ('antipasto', 1131), ('anytime', 371), ('aperitif', 63), ('aphis', 94), ('aphoristically', 2643), ('apolitical', 1594), ('apotheosized', 335), ('appellate', 164), ('appendage', 924), ('appetizer', 2745), ('apple', 531), ('apportioning', 692), ('appositive', 2802), ('apricots', 1199), ('aquaplanes', 2063), ('aquatics', 522), ('arbitrament', 109), ('arcane', 2471), ('archaeologists', 927), ('archers', 1446), ('archie', 1308), ('archipelago', 801), ('ardour', 2750), ('arguably', 877), ('arise', 64), ('aristocrat', 641), ('armoires', 1958), ('arraign', 701), ('arrogation', 1870), ('arrowhead', 815), ('artful', 191), ('arthurian', 1796), ('artificial', 1791), ('artillerists', 2373), ('artistry', 2344), ('ascending', 342), ('ascii', 703), ('asexual', 1432), ('asinine', 1202), ('asperse', 2801), ('assegais', 982), ('assignments', 1607), ('assistantships', 2013), ('assisted', 2302), ('assuaging', 1073), ('athenaeums', 2147), ('atolls', 2927), ('atriums', 2764), ('atropine', 2668), ('attacking', 108), ('attested', 2473), ('attuned', 722), ('attuning', 567), ('auctions', 1711), ('audits', 489), ('augured', 2596), ('authoritative', 68), ('authorizes', 880), ('autocross', 593), ('average', 902), ('averages', 2116), ('averted', 745), ('aviators', 2091), ('awaited', 607), ('awaken', 1056), ('awfully', 1274), ('awn ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-571944d4bf52> in <module>()
#      33         return merge(m_sort(arr[mid]), m_sort(arr[mid+1]))
#      34
# ---> 35 sorted_all = m_sort(sorted_partial)
#
# <ipython-input-46-571944d4bf52> in m_sort(arr)
#      31     else:
#      32         mid = len(arr)//2
# ---> 33         return merge(m_sort(arr[mid]), m_sort(arr[mid+1]))
#      34
#      35 sorted_all = m_sort(sorted_partial)
#
# <ipython-input-46-571944d4bf52> in m_sort(arr)
#      31     else:
#      32         mid = len(arr)//2
# ---> 33         return merge(m_sort(arr[mid]), m_sort(arr[mid+1]))
#      34
#      35 sorted_all = m_sort(sorted_partial)
#
# <ipython-input-46-571944d4bf52> in m_sort(arr)
#      31     else:
#      32         mid = len(arr)//2
# ---> 33         return merge(m_sort(arr[mid]), m_sort(arr[mid+1]))
#      34
#      35 sorted_all = m_sort(sorted_partial)
#
# <ipython-input-46-571944d4bf52> in m_sort(arr)
#      27
#      28 def m_sort(arr):
# ---> 29     if len(arr) < 2:
#      30         return arr
#      31     else:
#
# TypeError: object of type 'int' has no len()

# %%
# task 3.4

def bin_search(sorted_all, word):
    def b_search(sorted_all, word, lb, rb):
        if lb >= rb: # item not found in sorted_all
            return None
        else:
            mid = (rb + lb)//2
            if sorted_all[mid][0] == word: # compare first element of tuple to word
                return sorted_all[mid]
            elif sorted_all[mid][0] > word:
                return b_search(sorted_all, word, lb, mid-1)
            else:
                return b_search(sorted_all, word, mid+1, rb)
                
    return b_search(sorted_all, word, 0, len(sorted_all))

# %%
#task 3.5

def prefix_search(sorted_all, prefix):
    def pre_search(sorted_all, prefix, lb, rb, prefix_list):
        if lb > rb: # item not found in sorted_all
            return prefix_list
        else:
            mid = (rb + lb)//2
            print(mid)
            if prefix == sorted_all[mid][0][:len(prefix)]: # compare prefix of first element of tuple to prefix given
                prefix_list.append(sorted_all[mid])
                return pre_search(sorted_all, prefix, lb, mid-1, prefix_list)
            elif sorted_all[mid][0] > prefix:
                return pre_search(sorted_all, prefix, lb, mid-1, prefix_list)
            else:
                return pre_search(sorted_all, prefix, mid+1, rb, prefix_list)
            
    return pre_search(sorted_all, prefix, 0, len(sorted_all), [])

# %%
# task 3.6

def suffix_search(sorted_all, suffix):
    def suf_search(sorted_all, suffix, lb, rb, suffix_list):
        if lb > rb: # item not found in sorted_all
            return suffix_list
        else:
            mid = (rb + lb)//2
            print(mid)
            if suffix == sorted_all[mid][0][-len(prefix):]: # compare suffix of first element of tuple to suffix given
                suffix_list.append(sorted_all[mid])
                return suf_search(sorted_all, suffix, lb, mid-1, suffix_list)
            elif sorted_all[mid][0] > prefix:
                return suf_search(sorted_all, suffix, lb, mid-1, suffix_list)
            else:
                return suf_search(sorted_all, suffix, mid+1, rb, suffix_list)
            
    return suf_search(sorted_all, suffix, 0, len(sorted_all), [])
