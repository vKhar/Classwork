# %%
#Task 1
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_front(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node
        if self.tail is None:
            self.tail = self.head

    def insert_back(self, data):
        new_node = Node(data)
        if self.tail is None:
            self.head = self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node

    def remove_front(self):
        if self.head is None:
            return None
        node = self.head
        self.head = self.head.next
        if self.head is None:
            self.tail = None
        return node

    def remove_back(self):
        if self.head is None:
            return None
        if self.head.next is None:
            node = self.head
            self.head = self.tail = None
            return node
        current = self.head
        while current.next.next is not None:
            current = current.next
        node = current.next
        current.next = None
        self.tail = current
        return node

    def __repr__(self):
        node = self.head
        nodes = []
        while node is not None:
            nodes.append(str(node.data))
            node = node.next
        return " : ".join(nodes)

# %%
#task 1 test cases
LL = LinkedList()
LL.insert_back(8)
LL.insert_back(10)
LL.insert_front(4)
LL.insert_front(2)
print(LL)
print(LL.remove_front())
LL.remove_back()
print(LL)

# %%
#Task 1 Test Cases
ll = LinkedList()
ll.insert_front(1)
ll.insert_front(2)
ll.insert_back(3)
print(ll) # Output: 2 : 1 : 3
node = ll.remove_back()
print(node.data) # Output: 3
print(ll) # Output: 2 : 1

# %% [markdown]
# - 10/10

# %%
#Task 2
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_front(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node
        if self.tail is None:
            self.tail = self.head

    def insert_back(self, data):
        new_node = Node(data)
        if self.tail is None:
            self.head = self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node

    def remove_front(self):
        if self.head is None:
            return None
        node = self.head
        self.head = self.head.next
        if self.head is None:
            self.tail = None
        return node

    def remove_back(self):
        if self.head is None:
            return None
        if self.head.next is None:
            node = self.head
            self.head = self.tail = None
            return node
        current = self.head
        while current.next.next is not None:
            current = current.next
        node = current.next
        current.next = None
        self.tail = current
        return node

    def __repr__(self):
        node = self.head
        nodes = []
        while node is not None:
            nodes.append(str(node.data))
            node = node.next
        return " : ".join(nodes)
class PriorityStack(LinkedList):
    def __init__(self):
        super().__init__()

    def push(self, item, color):
        if color == "RED":
            self.insert_front((item, color))
        else:
            self.insert_back((item, color))

    def pop(self):
        current = self.head
        prev = None
        while current is not None:
            if current.data[1] == "RED":
                if prev is None:
                    self.head = current.next
                else:
                    prev.next = current.next
                return current.data[0]
            prev = current
            current = current.next
        current = self.head
        prev = None
        while current is not None:
            if prev is None:
                self.head = current.next
            else:
                prev.next = current.next
            return current.data[0]
        return None

# %%
## Task 2 Test Cases
ps = PriorityStack()
ps.push(123,"RED")
ps.push(456,"RED")
ps.push('abc',"GREEN")
ps.push('xyz',"GREEN")
print(
ps.pop(),
ps.pop(),
ps.pop(),
ps.pop(),
ps.pop()
)

# %% [markdown]
# ### Feedback
# - By inheriting from Linked List, you also make insert_front,..etc available in the Stack !!!
# - Is a Stack a Linked List ????!!!
# - YOU DO NOT UNDERSTAND OOP!!!
# - 0/8

# %%
#Task 2 Test Cases
pq = PriorityStack()
pq.push(1, "RED")
pq.push(2, "GREEN")
pq.push(3, "RED")
print(pq.pop()) # Output: 3
print(pq.pop()) # Output: 1
print(pq.pop()) # Output: 2
print(pq.pop()) # Output: None

# %%
#Task 3
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_front(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node
        if self.tail is None:
            self.tail = self.head

    def insert_back(self, data):
        new_node = Node(data)
        if self.tail is None:
            self.head = self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node

    def remove_front(self):
        if self.head is None:
            return None
        node = self.head
        self.head = self.head.next
        if self.head is None:
            self.tail = None
        return node

    def remove_back(self):
        if self.head is None:
            return None
        if self.head.next is None:
            node = self.head
            self.head = self.tail = None
            return node
        current = self.head
        while current.next.next is not None:
            current = current.next
        node = current.next
        current.next = None
        self.tail = current
        return node

    def __repr__(self):
        node = self.head
        nodes = []
        while node is not None:
            nodes.append(str(node.data))
            node = node.next
        return " : ".join(nodes)
class PriorityStack(LinkedList):
    def __init__(self):
        super().__init__()

    def push(self, item, color):
        if color == "RED":
            self.insert_front((item, color))
        else:
            self.insert_back((item, color))

    def pop(self):
        current = self.head
        prev = None
        while current is not None:
            if current.data[1] == "RED":
                if prev is None:
                    self.head = current.next
                else:
                    prev.next = current.next
                return current.data[0]
            prev = current
            current = current.next
        current = self.head
        prev = None
        while current is not None:
            if prev is None:
                self.head = current.next
            else:
                prev.next = current.next
            return current.data[0]
        return None
class HashTable:
    def __init__(self, size):
        self.buckets = [None for i in range(size)]
        self.size = size
        
    def insert(self, object):
        index = sum([ord(c) for c in object]) % self.size
        if not self.buckets[index]:
            self.buckets[index] = LinkedList()
            self.buckets[index].insert_front(object)
            return True
        else:
            self.buckets[index].insert_front(object)
            return True
    
    def remove(self, object):
        index = sum([ord(c) for c in object]) % self.size
        linked_list = self.buckets[index]
        if not linked_list:
            return False
        else:
            curr = linked_list.head
            prev = None
            while curr:
                if curr.data == object:
                    if prev:
                        prev.next = curr.next
                    else:
                        linked_list.head = curr.next
                    return True
                prev = curr
                curr = curr.next
            return False

# %%
ht = HashTable(3)
print(ht.insert("hello")) # True
print(ht.insert("world")) # True
print(ht.insert("world")) # True
print(ht.insert("hello")) # True
print(ht.remove("world")) # True
print(ht.remove("hello")) # True
print(ht.remove("world")) # True
print(ht.remove("hello")) # True
print(ht.remove("world")) # False

# %% [markdown]
# #### Feedback
# - You are allow to only use the operations provided by LinkedList and NOT TRY TO traverse the Linked List in the Stack!!
# - 5/10
