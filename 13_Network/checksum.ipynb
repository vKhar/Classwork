# %% [markdown]
# #### Checksum Error Detection Exercise
#     1.  Write a Python function to generate the checksum for a str of hexadecimal digits using the IP Checksum algorithm

# %%
def checksum(data:str)->str: ## str of hexadecimal digits
    ## Step 1: Group data into 4 hexadecimal digits and sum them
    ## Step 2: Check for carry over and add to lowest sig digit
    ## Step 3: 1's complement the result
    pass

## Kavish
def checksum(string):
    string = string.split(" ")
    octets = [string[i] + string[i+1] for i in range(0, len(string)-1, 2)]
    total = 0
    for i in range(len(octets)):
        new = hex(total + int(octets[i], base=16))[2:]
        if len(new) == 5:
            new = hex(int(new[1:], base=16) + 1)[2:]
        total = int(new, base=16)
    return hex(16**4 - 1 - total)

print(checksum("00 01 f2 03 f4 f5 f6 f7"))
# Out:
# 0x220d

# %% [markdown]
#     2.  Given the input payload string of hexadecimal digits:
#     "450005dc6d6b40008006dc6ec0a80159cf2e"
#
#     print the str of hexdecimal digits to be transmitted

# %% [markdown]
#     3.  Write a function to validate the transmitted data, returns True if valid, False if invalid

# %%
def validate(data:str)->bool:
    pass
