# %%
## helper function to print bytes in binary 
## Python does not have a built-in function to print bits
def print_bin(bytes_array: bytes)->str:
    print( ":".join (f"{i:^8d}" for i in range(len(bytes_array) ) ))
    print( ":".join ( f"{b:08b}" for b in bytes_array ) )

# %%
 ## writing text into a file the "normal" way
text = "Hello World"
f = open("text.txt", "w")
f.write(text)
f.close()

# %%
## writing text into a file in binary form
import string

text = "Hello World"
## encode text into bytes ( array of bytes)
text_bytes = text.encode("utf-8")

print_bin(text_bytes)
f = open("text.bin", "wb")
f.write(text_bytes)
f.close()

# %% [markdown]
# #### Unicode Table
# - The whole #@♁♝♘😛 table! (I have not seen the page finish loading ..)
#     - https://unicode-table.com/en/
#
#
# - In sections
#     - https://unicode-table.com/en/blocks/

# %% [markdown]
# - each hex digit (0,1,2,..,A,B,C,D,E,F) represents 4 bits (0000 to 1111)
# - a pair of hex digits represents one byte

# %%
### unicode literals , \u for 4 or \U for  8 hex digits
one_char = "a"
two_char = "\u058D" 
three_char = "\u4e50" ## stores as 2 bytes in utf-16  
four_char = "\U0001F921"

## Not every app can display all unicode code points

# %%
symbol = three_char
print(symbol)
bytes_array = symbol.encode("utf-8")

print_bin(bytes_array)

# %%
### Use of ord() to get the unicode point (ascii value) in decimal
ord("a")

### Use of chr() to map unicode point to symbol

# %% [markdown]
# ##### Encoding in Python
# - converting data into sequences of bytes
# - why do we need encoding/seralisation ?
#     - to be able to save and read data in a file
#     - to be able to send amd receive data over the network
# - endianess or byte order
#     - big endian : most significant byte store first
#     - little endian : least significant byte store first

# %%
## Using UTF-8, UTF-16BE, UTF-32BE
symbol = three_char
print(symbol)

bytes_stream = symbol.encode("utf-8")

print_bin(bytes_stream)
# Out:
# 乐
#    0    :   1    :   2
# 11100100:10111001:10010000

# %% [markdown]
# Excercise

# %%
#### writing unicodes to file
#### Task 1: Write 4 emoji symbols into a file


### Task 2: read the emoji symbols from file and print them

# %% [markdown]
# ____
# #### Integer representation in Python/ Encoding integers
# - using
#     - int.to_bytes() to encode int to bytes
#     - int.from_bytes() to decode from bytes to int
#     - need to know the size of int to encode

# %%
import sys
pos_n = sys.maxsize ## 0 to 2**63 -1 base on 2's complements encoding
neg_n = -(sys.maxsize)-1 ## -1 to -(2**63)
print(f"{neg_n} to {pos_n}")
# Out:
# -9223372036854775808 to 9223372036854775807

# %%
by_arry = pos_n.to_bytes(8,byteorder="big",signed=True)
print_bin(by_arry)

by_arry2 = neg_n.to_bytes(8,byteorder="big",signed=True)
print_bin(by_arry)
# Out:
#    0    :   1    :   2    :   3    :   4    :   5    :   6    :   7
# 01111111:11111111:11111111:11111111:11111111:11111111:11111111:11111111
#    0    :   1    :   2    :   3    :   4    :   5    :   6    :   7
# 01111111:11111111:11111111:11111111:11111111:11111111:11111111:11111111

# %%
 int.from_bytes(by_arry,byteorder='big',signed=True) + 10**1000
# Out:
# ...

# %% [markdown]
# ##### In Python 3 onwards, integer has NO LIMITS !!

# %%
## Python 3 onwards, int uses a variable length array of bytes
import math
def bits2bytes(i):
  return math.ceil(i/8)

import sys
new_max = sys.maxsize
new_max = new_max * (2 ** 2)
new_min = -(new_max)-1
print(f"new max is {new_max},size of new_max is {new_max.bit_length()} bits { bits2bytes(new_max.bit_length())} bytes")

by_arry = new_max.to_bytes(bits2bytes(new_max.bit_length()),byteorder="big",signed=True)
print_bin(by_arry)

by_arry = new_min.to_bytes(bits2bytes(new_max.bit_length()),byteorder="big",signed=True)
print_bin(by_arry)
# Out:
# new max is 36893488147419103228,size of new_max is 65 bits 9 bytes
#    0    :   1    :   2    :   3    :   4    :   5    :   6    :   7    :   8
# 00000001:11111111:11111111:11111111:11111111:11111111:11111111:11111111:11111100
#    0    :   1    :   2    :   3    :   4    :   5    :   6    :   7    :   8
# 11111110:00000000:00000000:00000000:00000000:00000000:00000000:00000000:00000011

# %% [markdown]
# - Using struct.pack to serialise int and float
# https://docs.python.org/3/library/struct.html
#
# <table class="docutils align-default">
# <colgroup>
# <col style="width: 10%" />
# <col style="width: 32%" />
# <col style="width: 24%" />
# <col style="width: 20%" />
# <col style="width: 15%" />
# </colgroup>
# <thead>
# <tr class="row-odd"><th class="head"><p>Format</p></th>
# <th class="head"><p>C Type</p></th>
# <th class="head"><p>Python type</p></th>
# <th class="head"><p>Standard size</p></th>
# <th class="head"><p>Notes</p></th>
# </tr>
# </thead>
# <tbody>
# <tr class="row-even"><td><p><code class="docutils literal notranslate"><span class="pre">x</span></code></p></td>
# <td><p>pad byte</p></td>
# <td><p>no value</p></td>
# <td></td>
# <td><p>(7)</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="docutils literal notranslate"><span class="pre">c</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">char</span></span></p></td>
# <td><p>bytes of length 1</p></td>
# <td><p>1</p></td>
# <td></td>
# </tr>
# <tr class="row-even"><td><p><code class="docutils literal notranslate"><span class="pre">b</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">signed</span><span class="w"> </span><span class="kt">char</span></span></p></td>
# <td><p>integer</p></td>
# <td><p>1</p></td>
# <td><p>(1), (2)</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="docutils literal notranslate"><span class="pre">B</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">unsigned</span><span class="w"> </span><span class="kt">char</span></span></p></td>
# <td><p>integer</p></td>
# <td><p>1</p></td>
# <td><p>(2)</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="docutils literal notranslate"><span class="pre">?</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">_Bool</span></span></p></td>
# <td><p>bool</p></td>
# <td><p>1</p></td>
# <td><p>(1)</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="docutils literal notranslate"><span class="pre">h</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">short</span></span></p></td>
# <td><p>integer</p></td>
# <td><p>2</p></td>
# <td><p>(2)</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="docutils literal notranslate"><span class="pre">H</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">unsigned</span><span class="w"> </span><span class="kt">short</span></span></p></td>
# <td><p>integer</p></td>
# <td><p>2</p></td>
# <td><p>(2)</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="docutils literal notranslate"><span class="pre">i</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">int</span></span></p></td>
# <td><p>integer</p></td>
# <td><p>4</p></td>
# <td><p>(2)</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="docutils literal notranslate"><span class="pre">I</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">unsigned</span><span class="w"> </span><span class="kt">int</span></span></p></td>
# <td><p>integer</p></td>
# <td><p>4</p></td>
# <td><p>(2)</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="docutils literal notranslate"><span class="pre">l</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">long</span></span></p></td>
# <td><p>integer</p></td>
# <td><p>4</p></td>
# <td><p>(2)</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="docutils literal notranslate"><span class="pre">L</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">unsigned</span><span class="w"> </span><span class="kt">long</span></span></p></td>
# <td><p>integer</p></td>
# <td><p>4</p></td>
# <td><p>(2)</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="docutils literal notranslate"><span class="pre">q</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">long</span><span class="w"> </span><span class="kt">long</span></span></p></td>
# <td><p>integer</p></td>
# <td><p>8</p></td>
# <td><p>(2)</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="docutils literal notranslate"><span class="pre">Q</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">unsigned</span><span class="w"> </span><span class="kt">long</span><span class="w"> </span><span class="kt">long</span></span></p></td>
# <td><p>integer</p></td>
# <td><p>8</p></td>
# <td><p>(2)</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="docutils literal notranslate"><span class="pre">n</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="n">ssize_t</span></span></p></td>
# <td><p>integer</p></td>
# <td></td>
# <td><p>(3)</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="docutils literal notranslate"><span class="pre">N</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="n">size_t</span></span></p></td>
# <td><p>integer</p></td>
# <td></td>
# <td><p>(3)</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="docutils literal notranslate"><span class="pre">e</span></code></p></td>
# <td><p>(6)</p></td>
# <td><p>float</p></td>
# <td><p>2</p></td>
# <td><p>(4)</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="docutils literal notranslate"><span class="pre">f</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">float</span></span></p></td>
# <td><p>float</p></td>
# <td><p>4</p></td>
# <td><p>(4)</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="docutils literal notranslate"><span class="pre">d</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">double</span></span></p></td>
# <td><p>float</p></td>
# <td><p>8</p></td>
# <td><p>(4)</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="docutils literal notranslate"><span class="pre">s</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">char</span><span class="p">[</span><span class="p">]</span></span></p></td>
# <td><p>bytes</p></td>
# <td></td>
# <td><p>(9)</p></td>
# </tr>
# <tr class="row-odd"><td><p><code class="docutils literal notranslate"><span class="pre">p</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">char</span><span class="p">[</span><span class="p">]</span></span></p></td>
# <td><p>bytes</p></td>
# <td></td>
# <td><p>(8)</p></td>
# </tr>
# <tr class="row-even"><td><p><code class="docutils literal notranslate"><span class="pre">P</span></code></p></td>
# <td><p><span class="c-expr sig sig-inline c"><span class="kt">void</span><span class="p">*</span></span></p></td>
# <td><p>integer</p></td>
# <td></td>
# <td><p>(5)</p></td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ##### converting a signed int to binary representation

# %%
import struct

## convert a signed int to 8-bit [-128 to 127],  32-bit [-2^31 to 2^31-1]
i = 10 #  
n_i = -10  #


bytes_array = struct.pack(">b", i)
print_bin(bytes_array)
bytes_array = struct.pack(">b", n_i)
print_bin(bytes_array)

# %%
import struct
import sys
value= (sys.maxsize)  # 64 bit signed int -2^63 to 2^63 -1 
print(value, (-2**63), 2**63 -1 )
by_arry= struct.pack('>q', value)  ## BE 32 bit
#q 64bit signed int, 32bit f, 64bit

# %% [markdown]
# #### Representing a  float in IEEE 754/ encoding float point numbers
# https://www.wikihow.com/Convert-a-Number-from-Decimal-to-IEEE-754-Floating-Point-Representation

# %% [markdown]
# ```
# 8.625
# 1) seperate whole number portion, fraction portion convert to binary
# > 00001000.101
# 2) normalised
# > 1.000101*2^3
# 3) convert exponent to bias 127, by adding 127,
# > 3+127= 130 =10000010
# 4)drop the 1,
# > mantissa = 000101
# 5) sign = 0
# 6) concatenate sign(1)+exponent(8)+mantissa(23)
# ```
# 0<span style="color:red">1000001 0</span>0001010 00000000 00000000

# %%
## Convert a floating point number to 32 bit signed 
import struct

value=8.625
by_array= struct.pack('>d', value) #big endian float
print_bin(by_array)
# Out:
#    0    :   1    :   2    :   3    :   4    :   5    :   6    :   7
# 01000000:00100001:01000000:00000000:00000000:00000000:00000000:00000000

# %% [markdown]
# ##### Overflow Problems in floating point arithmetic

# %%
0.1 + 0.1 + 0.1 == 0.3
# Out:
# False

# %%
import struct
double1  = struct.pack(">d",0.3)
double2  = struct.pack(">d",0.1 + 0.1 + 0.1)

print_bin(double1)
print_bin(double2)
# Out:
#    0    :   1    :   2    :   3    :   4    :   5    :   6    :   7
# 00111111:11010011:00110011:00110011:00110011:00110011:00110011:00110011
#    0    :   1    :   2    :   3    :   4    :   5    :   6    :   7
# 00111111:11010011:00110011:00110011:00110011:00110011:00110011:00110100

# %% [markdown]
# ___
# ##### Appendix

# %% [markdown]
# <li>
# IEEE 754 double precision exponent has 11 bit : range of values is 0  to 2047
# <li> to store signed integer using 1023 bias , we have -1023 to 1023

# %%
max_value = (1.5 * 2**1023)
print(max_value)
inf = float("inf")
inf_bites = struct.pack(">d",inf)
max_bites = struct.pack(">d",max_value)
print_bin(inf_bites)
print_bin(max_bites)
# Out:
# 1.348269851146737e+308
#    0    :   1    :   2    :   3    :   4    :   5    :   6    :   7
# 01111111:11110000:00000000:00000000:00000000:00000000:00000000:00000000
#    0    :   1    :   2    :   3    :   4    :   5    :   6    :   7
# 01111111:11101000:00000000:00000000:00000000:00000000:00000000:00000000

# %%
## Number of bytes to represent an integer
import math
def byte_count(i:int)->int:
    return math.ceil (i.bit_length()/8)

# %%
## example of using struct
import struct
L = [1,2,3]
bites = struct.pack(f"{len(L)}b", *L) 
print_bin(bites)

# %%
### Writing the following in binary form
L = [1,2,3.02,"hello"]

import struct
bytes_array = struct.pack("2b",*L[:2])
bytes_array+= struct.pack("f",L[2])
bytes_array+= L[-1].encode()

f = open("bin.bin","wb")
f.write(bytes_array)
f.close()

# %%
print_bin(bytes_array)
